# %% [markdown]
# #### Load Env Variables

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# #### Connect with Google Gemini Model

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

# %%
res = llm.invoke("What is rose? explain me in short. ")
print(res.content)
# Out:
# A **rose** is a **flowering shrub** known for its beautiful, often fragrant **flowers** that come in many colors and varieties. It's a popular symbol of love and beauty.

# %% [markdown]
# #### Connect with OpenAI Model

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4o")

# %%
res = llm.invoke("How to find largest number from a list in python?")
print(res.content)
# Out:
# To find the largest number in a list in Python, you can use the built-in `max()` function, which is designed to return the largest item in an iterable, such as a list. Here's a simple example:
#
# ```python
# # Sample list
# numbers = [3, 41, 12, 9, 74, 15]
#
# # Find the largest number
# largest_number = max(numbers)
#
# # Print the largest number
# print("The largest number is:", largest_number)
# ```
#
# Alternatively, you can implement this functionality manually using a loop. Here's how you can do it:
#
# ```python
# # Sample list
# numbers = [3, 41, 12, 9, 74, 15]
#
# # Assume the first number is the largest for now
# largest_number = numbers[0]
#
# # Loop through each number in the list
# for number in numbers:
#     # If the current number is greater than the largest found so far, update largest_number
#     if number > largest_number:
#         largest_number = number
#
# # Print the largest number
# print("The largest number is:", largest_number)
# ```
#
# ...

# %% [markdown]
# #### Connect with ANTHROPIC

# %%
from langchain_anthropic import ChatAnthropic
llm = ChatAnthropic(model="claude-haiku-4-5-20251001")

# %%
res = llm.invoke("what is loop?")
print(res.content)
# Out:
# # What is a Loop?
#
# A **loop** is a programming construct that repeats a block of code multiple times until a certain condition is met.
#
# ## Why Use Loops?
#
# Instead of writing the same code over and over:
# ```python
# print("Hello 1")
# print("Hello 2")
# print("Hello 3")
# print("Hello 4")
# print("Hello 5")
# ```
#
# You can use a loop to do it efficiently:
# ```python
# for i in range(1, 6):
#     print(f"Hello {i}")
# ```
#
# ## Main Types of Loops
#
# ### 1. **For Loop**
# Repeats a fixed number of times
# ```python
# for i in range(5):
#     print(i)  # Prints 0, 1, 2, 3, 4
# ```
#
# ### 2. **While Loop**
# Repeats until a condition becomes false
# ```python
# count = 0
# while count < 5:
#     print(count)
#     count += 1
# ```
#
# ### 3. **Do-While Loop** (in some languages)
# Executes at least once, then repeats while condition is true
#
# ## Key Benefits
#
# ✅ **Reduces code repetition**
# ✅ **Makes code cleaner and easier to read**
# ...

# %% [markdown]
# #### Static Prompts

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4o")

# %%
prompts = [
    ("system", "You are a java developer"),     ### (type, )  "system",  "ai", "user"
    ("user", "How to sort the array.")
]

res = llm.invoke(prompts)
print(res.content)
# Out:
# Sorting an array in Java can be done using different approaches depending on whether you're dealing with arrays of primitive data types or objects, and whether you want ascending or descending order. Here are some common methods to sort arrays:
#
# ### 1. Using the Arrays class
#
# Java provides a utility class called `Arrays` in the `java.util` package that has several static methods to sort arrays:
#
# #### For Primitive Data Types
#
# To sort an array of primitive data types (such as `int`, `char`, `double`, etc.) in ascending order, you can use:
#
# ```java
# import java.util.Arrays;
#
# public class SortArray {
#     public static void main(String[] args) {
#         int[] numbers = {4, 3, 2, 1};
#         Arrays.sort(numbers);  // Sorts in ascending order
#         System.out.println(Arrays.toString(numbers));
#     }
# }
# ```
#
# #### For Objects
#
# If you have an array of objects (such as `String`), you can also use `Arrays.sort()`:
#
# ```java
# import java.util.Arrays;
#
# ...
